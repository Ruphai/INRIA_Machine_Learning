# %% [markdown]
# # Penguins Species Prediction
# Given a problem case, where we have to predict the species of penguins based on their body measurements -- Culmen Length and Culmen Depth. As a junior Data Analyst, you have been assigned to Extract the features and visualize it to decide if a Machine Learning Algorithm would be best or some other statistical model.

# %% [markdown]
# The Initial step would be to determine what the features and the targets are.
# ## Data
# For this use case, the Open ML dataset for Penguin Classification has been used. The data can be found at https://www.openml.org/d/42585. The data was provided by Dr. Kristen Gorman and the Palmer Station, Antarctica LTER, a member of the Long Term Ecological Research Network as a replacement to the popular iris dataset.

# %%
import pandas as pd
penguins = pd.read_csv('penguins.csv')

# %% [markdown]
# A brief Look at the data to identify the features and the target classes. And extract the numerical and categorical variables.

# %%
penguins.head()
# Out:
#   species     island culmen_length_mm culmen_depth_mm flipper_length_mm  \
# 0  Adelie  Torgersen             39.1            18.7               181
# 1  Adelie  Torgersen             39.5            17.4               186
# 2  Adelie  Torgersen             40.3              18               195
# 3  Adelie  Torgersen                ?               ?                 ?
# 4  Adelie  Torgersen             36.7            19.3               193
#
#   body_mass_g     sex
# 0        3750    MALE
# 1        3800  FEMALE
# 2        3250  FEMALE
# 3           ?       ?
# 4        3450  FEMALE

# %%
penguins.tail()
# Out:
#     species  island culmen_length_mm culmen_depth_mm flipper_length_mm  \
# 339  Gentoo  Biscoe                ?               ?                 ?
# 340  Gentoo  Biscoe             46.8            14.3               215
# 341  Gentoo  Biscoe             50.4            15.7               222
# 342  Gentoo  Biscoe             45.2            14.8               212
# 343  Gentoo  Biscoe             49.9            16.1               213
#
#     body_mass_g     sex
# 339           ?       ?
# 340        4850  FEMALE
# 341        5750    MALE
# 342        5200  FEMALE
# 343        5400    MALE

# %%
penguins.sample(10)
# Out:
#        species     island culmen_length_mm culmen_depth_mm flipper_length_mm  \
# 227     Gentoo     Biscoe             46.7            15.3               219
# 11      Adelie  Torgersen             37.8            17.3               180
# 123     Adelie  Torgersen             41.4            18.5               202
# 152  Chinstrap      Dream             46.5            17.9               192
# 13      Adelie  Torgersen             38.6            21.2               191
# 36      Adelie      Dream             38.8              20               190
# 70      Adelie  Torgersen             33.5              19               190
# 237     Gentoo     Biscoe             49.2            15.2               221
# 170  Chinstrap      Dream             46.4            18.6               190
# 48      Adelie      Dream               36            17.9               190
#
#     body_mass_g     sex
# 227        5200    MALE
# 11         3700       ?
# 123        3875    MALE
# 152        3500  FEMALE
# 13         3800    MALE
# 36         3950    MALE
# 70         3600  FEMALE
# 237        6300    MALE
# 170        3450  FEMALE
# 48         3450  FEMALE

# %%
# From the quick look at the data, we can tell that the following are types of the data within the dataframe.
target_column = 'species'
numerical = [
    'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']

categorical = ['island', 'sex']

columns = numerical + categorical + [target_column]

# %% [markdown]
# We could take a quick look at the species and sex of the penguins within our datasets and the number of samples we have.

# %%
penguins['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins['sex'].value_counts()
# Out:
# MALE      168
# FEMALE    165
# ?          10
# _           1
# Name: sex, dtype: int64

# %% [markdown]
# The output shows us a complete set of data for the Species but some data gaps in the sex with about ten undecided classes for the penguin sex. This could be resolved at a later stage, when we have developed our predictive model.

# %%
import seaborn as sns
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
_ = penguins.hist(penguins[flipper_length_mm])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-acb5e820f1f6> in <module>
# ----> 1 _ = penguins.hist(penguins[flipper_length_mm])
#
# NameError: name 'flipper_length_mm' is not defined

# %%
columns = ['culmen_depth_mm', 'culmen_length_mm']
_ = sns.pairplot(data = penguins, vars = columns, hue = target_column, height = 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c026d877ab46> in <module>
#       1 columns = ['culmen_depth_mm', 'culmen_length_mm']
# ----> 2 _ = sns.pairplot(data = penguins, vars = columns, hue = target_column, height = 5)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2020     elif diag_kind == "kde":
#    2021         diag_kws.setdefault("fill", True)
# -> 2022         grid.map_diag(kdeplot, **diag_kws)
#    2023
#    2024     # Maybe plot on the off-diagonals
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1400             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1401             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1402             func(x=vector, **plot_kwargs)
#    1403             self._clean_axis(ax)
#    1404
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1718     )
#    1719
# -> 1720     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1721
#    1722     if p.univariate:
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _attach(self, obj, allowed_types, log_scale)
#    1116                     f"{allowed_types} is required"
#    1117                 )
# -> 1118                 raise TypeError(err)
#    1119
#    1120             # Register with the matplotlib unit conversion machinery
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %%
penguins.tail()
# Out:
#     species  island culmen_length_mm culmen_depth_mm flipper_length_mm  \
# 339  Gentoo  Biscoe                ?               ?                 ?
# 340  Gentoo  Biscoe             46.8            14.3               215
# 341  Gentoo  Biscoe             50.4            15.7               222
# 342  Gentoo  Biscoe             45.2            14.8               212
# 343  Gentoo  Biscoe             49.9            16.1               213
#
#     body_mass_g     sex
# 339           ?       ?
# 340        4850  FEMALE
# 341        5750    MALE
# 342        5200  FEMALE
# 343        5400    MALE
